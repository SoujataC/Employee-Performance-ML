# %% [markdown]
#  # visualize

# %%
# data analysis
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# for Plotly 
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go

# Machine Learning
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
file = r'Employee_Performance.xls'
EmpPer= pd.read_excel(file)

# %%
EmpPer.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# 1                  4        ...                                    4
# 2                  4        ...                                    3
# 3                  4        ...                                    2
# 4                  4        ...                                    4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Random Forest

# %%
#label Encoding
X=EmpPer.iloc[:,1:-1] #for integer-location based indexing / selection by position in the dataFrame
y=EmpPer.PerformanceRating

enc = LabelEncoder()
X.Gender = enc.fit_transform(X.Gender)
X.EducationBackground = enc.fit_transform(X.EducationBackground)
X.MaritalStatus = enc.fit_transform(X.MaritalStatus)
X.EmpDepartment = enc.fit_transform(X.EmpDepartment)
X.EmpJobRole = enc.fit_transform(X.EmpJobRole)
X.BusinessTravelFrequency = enc.fit_transform(X.BusinessTravelFrequency)
X.OverTime=enc.fit_transform(X.OverTime)
X.Attrition = enc.fit_transform(X.Attrition)

#Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=8)

#Random Forest Classifier
model = RandomForestClassifier(n_estimators=16 ,max_depth = 7, random_state=8)
model.fit(X_train,y_train)

y_predict=model.predict(X_test)
print(accuracy_score(y_test,y_predict))
# Out:
# 0.9533333333333334

# %% [markdown]
# ## 1. Top 3 Important Factors effecting employee performance

# %%
F_imp = pd.DataFrame(model.feature_importances_)
F_imp.index = X.columns
F_imp.columns = ['Employee performance']
F_imp.sort_values( by = 'Employee performance',ascending=False)
# Out:
#                               Employee performance
# EmpLastSalaryHikePercent                  0.239343
# EmpEnvironmentSatisfaction                0.227086
# YearsSinceLastPromotion                   0.134272
# EmpJobRole                                0.049215
# ExperienceYearsInCurrentRole              0.038640
# EmpDepartment                             0.030356
# ExperienceYearsAtThisCompany              0.029914
# EmpWorkLifeBalance                        0.028394
# Age                                       0.027255
# EmpHourlyRate                             0.026069
# TotalWorkExperienceInYears                0.022364
# YearsWithCurrManager                      0.021157
# DistanceFromHome                          0.014401
# EmpJobInvolvement                         0.012519
# TrainingTimesLastYear                     0.011170
# EmpRelationshipSatisfaction               0.010794
# MaritalStatus                             0.010232
# EmpJobSatisfaction                        0.009648
# EducationBackground                       0.008898
# EmpEducationLevel                         0.008847
# BusinessTravelFrequency                   0.007973
# EmpJobLevel                               0.007510
# NumCompaniesWorked                        0.007061
# Attrition                                 0.006384
# OverTime                                  0.005985
# Gender                                    0.004515

# %% [markdown]
# ## 2. Department wise performances

# %% [markdown]
# The 6 departments are : -
#
# i) Sales ii) Human Resoruces iii) Development iv) Data Science v) Reserch & Development vi) Finamce

# %% [markdown]
# ### Sales Department

# %%
sales = EmpPer[EmpPer.EmpDepartment == 'Sales']  
sales.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single         Sales
# 1  E1001006   47   Male           Marketing        Single         Sales
# 2  E1001007   40   Male       Life Sciences       Married         Sales
# 4  E1001010   60   Male           Marketing        Single         Sales
# 6  E1001016   50   Male           Marketing       Married         Sales
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0       Sales Executive           Travel_Rarely                10
# 1       Sales Executive           Travel_Rarely                14
# 2       Sales Executive       Travel_Frequently                 5
# 4       Sales Executive           Travel_Rarely                16
# 6  Sales Representative           Travel_Rarely                 8
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# 1                  4        ...                                    4
# 2                  4        ...                                    3
# 4                  4        ...                                    4
# 6                  4        ...                                    4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 4                          10                      1                   3
# 6                           4                      2                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 4                             2                             2
# 6                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 4                       2                     2         No                  3
# 6                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(sales['PerformanceRating'], sales['Age'], palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=sales, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(sales['Gender'], sales['PerformanceRating'], palette="cubehelix")
# Out:
# C:\Users\princ\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': sales['TotalWorkExperienceInYears'],
        'y': sales['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':sales['ExperienceYearsAtThisCompany'],
        'y':sales['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': sales['ExperienceYearsInCurrentRole'],
        'y': sales['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Sales',
}
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="eee39a04-32f3-4c9a-b7b4-5f01053970c0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eee39a04-32f3-4c9a-b7b4-5f01053970c0", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [10, 20, 20, 10, 4, 28, 10, 1, 2, 34, 6, 9, 8, 6, 10, 6, 5, 3, 6, 6, 9, 12, 8, 29, 18, 35, 18, 9, 5, 10, 3, 28, 10, 8, 10, 2, 3, 10, 13, 9, 1, 1, 16, 17, 3, 5, 22, 10, 12, 9, 22, 12, 10, 9, 21, 19, 7, 33, 23, 19, 3, 26, 16, 14, 1, 8, 13, 18, 2, 5, 4, 15, 9, 23, 10, 3, 5, 22, 6, 6, 11, 22, 9, 10, 7, 1, 28, 8, 5, 15, 10, 5, 26, 26, 26, 4, 31, 23, 10, 9, 10, 10, 19, 10, 11, 10, 17, 5, 8, 24, 3, 5, 8, 14, 8, 4, 6, 6, 15, 1, 8, 6, 5, 13, 5, 15, 4, 11, 5, 16, 1, 1, 10, 11, 5, 23, 10, 9, 6, 7, 18, 8, 10, 9, 36, 10, 15, 11, 27, 10, 10, 0, 7, 2, 13, 10, 6, 10, 2, 7, 19, 6, 10, 17, 4, 13, 16, 10, 10, 21, 6, 2, 12, 13, 8, 11, 15, 6, 1, 13, 6, 7, 23, 10, 37, 9, 20, 5, 10, 7, 4, 7, 25, 9, 1, 1, 10, 9, 9, 12, 14, 8, 9, 10, 7, 10, 6, 29, 14, 6, 14, 9, 20, 10, 7, 10, 15, 21, 15, 16, 3, 3, 6, 16, 2, 1, 10, 8, 15, 14, 10, 12, 8, 20, 21, 5, 17, 8, 31, 10, 22, 3, 2, 10, 9, 10, 14, 9, 5, 9, 28, 16, 24, 3, 9, 11, 11, 12, 4, 5, 38, 6, 12, 25, 8, 12, 0, 16, 4, 12, 6, 10, 13, 9, 15, 6, 12, 12, 1, 9, 24, 4, 10, 14, 7, 16, 9, 23, 16, 13, 11, 10, 32, 22, 33, 4, 10, 13, 28, 10, 7, 8, 20, 2, 8, 23, 12, 22, 0, 13, 13, 5, 13, 12, 9, 6, 6, 10, 8, 7, 5, 4, 8, 3, 7, 16, 3, 8, 8, 1, 7, 18, 9, 1, 10, 8, 5, 6, 10, 6, 3, 21, 10, 32, 15, 4, 10, 14, 37, 16, 15, 10, 9, 10, 0, 20, 5, 10, 22, 6, 7, 9, 13, 17, 8, 5, 3, 6, 4, 8, 12, 6, 4], "y": [3, 3, 4, 3, 3, 3, 4, 3, 3, 4, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 2, 2, 3, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 2, 3, 4, 3, 2, 3, 4, 3, 3, 3, 3, 3, 2, 2, 3, 3, 4, 3, 3, 3, 2, 3, 3, 3, 2, 3, 2, 3, 4, 2, 3, 3, 2, 2, 2, 3, 2, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 2, 2, 4, 3, 2, 2, 3, 4, 3, 3, 3, 3, 2, 3, 3, 2, 3, 4, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 4, 2, 3, 3, 3, 4, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 3, 3, 4, 2, 3, 3, 2, 2, 3, 3, 2, 3, 3, 2, 4, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 2, 2, 2, 3, 2, 2, 3, 3, 3, 3, 2, 4, 4, 3, 2, 4, 3, 3, 2, 3, 3, 2, 2, 3, 2, 3, 3, 3, 3, 2, 3, 2, 3, 2, 2, 3, 3, 3, 3, 3, 3, 2, 3, 4, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 3, 2, 2, 3, 3, 2, 4, 4, 3, 2, 3, 2, 3, 3, 3, 3, 3, 3, 2, 2, 4, 3, 4, 2, 3, 3, 3, 3, 3, 4, 4, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 2, 3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 3, 2, 3, 3, 4, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 3, 3, 3, 4, 4, 3, 4, 2], "type": "box", "uid": "ca148288-a3a7-4298-8250-92b26fd72e9b"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [10, 7, 18, 2, 2, 22, 8, 1, 2, 34, 6, 8, 5, 6, 10, 4, 4, 3, 3, 3, 9, 9, 8, 20, 18, 5, 5, 1, 5, 10, 2, 2, 5, 7, 10, 2, 3, 5, 7, 9, 1, 1, 16, 14, 3, 5, 17, 8, 10, 8, 1, 7, 10, 9, 1, 1, 2, 32, 12, 18, 2, 9, 15, 6, 1, 7, 9, 1, 2, 0, 3, 15, 8, 12, 1, 2, 5, 9, 5, 6, 11, 21, 6, 10, 4, 1, 26, 4, 0, 7, 10, 4, 22, 24, 11, 3, 29, 21, 10, 5, 8, 10, 19, 9, 7, 10, 15, 1, 6, 19, 1, 5, 5, 4, 5, 3, 3, 6, 5, 1, 3, 3, 5, 13, 4, 13, 2, 1, 3, 15, 1, 1, 10, 5, 4, 13, 10, 8, 5, 3, 8, 2, 10, 4, 36, 9, 1, 7, 1, 10, 5, 0, 2, 2, 11, 10, 6, 10, 2, 6, 9, 6, 10, 13, 1, 10, 2, 0, 4, 21, 5, 2, 7, 11, 5, 0, 15, 2, 1, 12, 2, 2, 22, 10, 16, 3, 4, 5, 8, 7, 0, 2, 19, 9, 1, 1, 10, 5, 8, 4, 5, 5, 4, 10, 7, 3, 0, 1, 0, 5, 14, 8, 1, 10, 7, 10, 2, 20, 11, 15, 2, 2, 5, 9, 2, 1, 9, 8, 15, 5, 10, 6, 6, 3, 20, 4, 9, 6, 25, 9, 2, 3, 2, 5, 9, 9, 9, 4, 2, 9, 21, 15, 1, 0, 9, 10, 11, 11, 3, 5, 37, 6, 5, 25, 7, 7, 0, 2, 2, 9, 2, 10, 7, 9, 12, 4, 10, 8, 0, 5, 24, 4, 10, 14, 7, 1 ...

# %% [markdown]
# ### Human Resoruces Department

# %%
HR = EmpPer[EmpPer.EmpDepartment == 'Human Resources']
HR.head()
# Out:
#    EmpNumber  Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 3   E1001009   41    Male     Human Resources      Divorced  Human Resources
# 16  E1001038   39  Female     Human Resources       Married  Human Resources
# 58  E1001107   36    Male     Human Resources       Married  Human Resources
# 81  E1001147   28    Male             Medical      Divorced  Human Resources
# 85  E1001156   36    Male       Life Sciences       Married  Human Resources
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 3           Manager           Travel_Rarely                10
# 16  Human Resources           Travel_Rarely                 3
# 58  Human Resources           Travel_Rarely                13
# 81  Human Resources           Travel_Rarely                 8
# 85  Human Resources           Travel_Rarely                 8
#
#     EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 3                   4        ...                                    2
# 16                  3        ...                                    3
# 58                  3        ...                                    2
# 81                  2        ...                                    4
# 85                  3        ...                                    3
#
#     TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 3                           23                      2                   2
# 16                          12                      3                   1
# 58                           8                      2                   3
# 81                           6                      6                   3
# 85                           6                      3                   3
#
#     ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 3                             21                             6
# 16                             8                             3
# 58                             5                             2
# 81                             5                             1
# 85                             5                             4
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 3                       12                     6         No                  3
# 16                       3                     6         No                  3
# 58                       0                     4         No                  3
# 81                       0                     4         No                  3
# 85                       0                     3         No                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(HR['PerformanceRating'], HR['Age'],palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=HR, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(HR['Gender'], HR['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': HR['TotalWorkExperienceInYears'],
        'y': HR['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':HR['ExperienceYearsAtThisCompany'],
        'y':HR['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': HR['ExperienceYearsInCurrentRole'],
        'y': HR['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - HR ',
    }
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="3427ff80-f0e1-426a-8a5d-d426716e2d6b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3427ff80-f0e1-426a-8a5d-d426716e2d6b", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [23, 12, 8, 6, 6, 13, 7, 6, 24, 6, 5, 10, 14, 10, 36, 33, 21, 10, 8, 2, 21, 10, 27, 14, 8, 10, 9, 3, 6, 10, 19, 13, 2, 3, 1, 10, 1, 7, 35, 6, 9, 16, 7, 23, 8, 12, 7, 9, 4, 1, 11, 32, 10, 16], "y": [3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 4, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 2, 2, 3, 3, 3, 2, 3, 3], "type": "box", "uid": "98f823d1-a717-44a4-b335-8e9b87941f9e"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [21, 8, 5, 5, 5, 5, 4, 6, 20, 5, 5, 4, 10, 7, 7, 33, 20, 10, 3, 2, 21, 6, 5, 10, 2, 3, 5, 2, 4, 9, 10, 11, 1, 3, 1, 10, 1, 6, 10, 2, 9, 4, 3, 5, 8, 11, 2, 2, 3, 1, 3, 32, 2, 9], "y": [3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 4, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 2, 2, 3, 3, 3, 2, 3, 3], "type": "box", "uid": "e0893aab-2eba-4ea2-ade5-db53857210d2"}, {"boxmean": false, "marker": {"color": "#FF851B"}, "name": "ExperienceYearsInCurrentRole", "orientation": "h", "x": [6, 3, 2, 1, 4, 4, 3, 3, 6, 4, 4, 3, 9, 6, 3, 9, 7, 9, 2, 2, 7, 3, 2, 7, 2, 2, 0, 2, 2, 7, 0, 10, 0, 2, 0, 1, 0, 2, 9, 0, 0, 2, 2, 3, 7, 9, 2, 2, 2, 0, 2, 5, 2, 7], "y": [3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 4, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 2, 2, 3, 3, 3, 2, 3, 3], "type": "box", "uid": "74905b97-8b8c-44eb-9a8d-a01aa99d169f"}], {"boxmode": "group", "title": "Performance According to the Experience Level - HR ", "xaxis": {"title": "Number Of Years", "zeroline": false}, "yaxis": {"title": "Performance Rating ", "zeroline": false}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("3427ff80-f0e1-426a-8a5d-d426716e2d6b"));});</script>

# %% [markdown]
# ### Development Department

# %%
Development = EmpPer[EmpPer.EmpDepartment == 'Development']  
Development.head()
# Out:
#    EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 5   E1001011   27    Male       Life Sciences      Divorced   Development
# 7   E1001019   28  Female       Life Sciences        Single   Development
# 8   E1001020   36  Female       Life Sciences       Married   Development
# 9   E1001021   38  Female       Life Sciences        Single   Development
# 10  E1001022   44    Male             Medical        Single   Development
#
#    EmpJobRole BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 5   Developer       Travel_Frequently                10                  2
# 7   Developer           Travel_Rarely                 1                  2
# 8   Developer              Non-Travel                 8                  3
# 9   Developer           Travel_Rarely                 1                  3
# 10  Developer              Non-Travel                24                  3
#
#           ...          EmpRelationshipSatisfaction  \
# 5         ...                                    3
# 7         ...                                    4
# 8         ...                                    1
# 9         ...                                    4
# 10        ...                                    3
#
#     TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 5                            9                      4                   2
# 7                           10                      4                   3
# 8                           10                      2                   3
# 9                           10                      4                   4
# 10                           9                      5                   3
#
#     ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 5                              9                             7
# 7                              7                             7
# 8                              8                             7
# 9                              1                             0
# 10                             5                             2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 5                        1                     7         No                  4
# 7                        3                     7        Yes                  3
# 8                        0                     5         No                  3
# 9                        0                     0         No                  3
# 10                       1                     4         No                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(Development['PerformanceRating'], Development['Age'],palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=Development, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(Development['Gender'], Development['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': Development['TotalWorkExperienceInYears'],
        'y': Development['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':Development['ExperienceYearsAtThisCompany'],
        'y':Development['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': Development['ExperienceYearsInCurrentRole'],
        'y': Development['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Development ',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="861eede1-9ac1-4aa1-9cc0-a5e6c4d1d1b3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("861eede1-9ac1-4aa1-9cc0-a5e6c4d1d1b3", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [9, 10, 10, 10, 9, 7, 10, 30, 5, 9, 19, 16, 10, 7, 10, 2, 5, 5, 11, 10, 9, 6, 17, 6, 8, 1, 9, 30, 1, 14, 26, 10, 10, 7, 8, 5, 10, 12, 1, 10, 13, 22, 9, 17, 8, 0, 10, 6, 6, 9, 4, 10, 8, 10, 4, 6, 8, 33, 12, 31, 1, 8, 3, 4, 6, 8, 1, 1, 6, 24, 10, 8, 15, 5, 20, 16, 1, 10, 9, 26, 20, 4, 3, 5, 8, 32, 6, 21, 9, 7, 22, 6, 8, 12, 1, 17, 6, 5, 3, 6, 10, 1, 6, 5, 13, 8, 26, 10, 24, 7, 9, 6, 6, 6, 1, 1, 1, 12, 8, 1, 23, 2, 10, 15, 4, 10, 7, 9, 10, 29, 17, 6, 25, 5, 2, 6, 1, 10, 5, 11, 10, 6, 17, 5, 11, 22, 21, 17, 1, 16, 17, 28, 2, 1, 9, 6, 12, 14, 7, 23, 5, 40, 3, 16, 18, 7, 18, 9, 19, 5, 8, 7, 1, 20, 10, 9, 6, 5, 12, 1, 21, 13, 8, 6, 13, 12, 19, 4, 1, 2, 9, 5, 5, 8, 21, 10, 21, 34, 7, 8, 7, 22, 8, 10, 11, 14, 9, 6, 7, 5, 15, 17, 4, 8, 5, 7, 16, 10, 6, 4, 6, 22, 8, 13, 4, 9, 2, 13, 17, 9, 17, 20, 10, 5, 10, 1, 5, 9, 5, 6, 21, 37, 5, 3, 15, 10, 28, 21, 5, 17, 19, 10, 5, 22, 4, 0, 4, 13, 19, 11, 19, 6, 24, 3, 12, 21, 9, 25, 4, 10, 11, 21, 10, 12, 7, 8, 12, 11, 17, 8, 16, 13, 15, 10, 3, 6, 10, 26, 6, 30, 7, 2, 3, 18, 18, 25, 20, 24, 13, 8, 15, 4, 21, 10, 6, 28, 8, 19, 11, 33, 3, 9, 10, 6, 28, 20, 26, 6, 19, 14, 13, 15, 8, 10, 12, 4, 8, 10, 10, 10, 1, 12, 28, 18, 8, 31, 6, 1, 6, 6, 6, 10, 21, 8, 10, 21, 26, 3, 6, 1, 10, 3, 10, 17, 13, 1, 10, 5, 10, 4, 20], "y": [4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 3, 3, 3, 4, 4, 3, 3, 4, 3, 3, 3, 3, 3, 2, 3, 4, 4, 3, 3, 2, 2, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 3, 3, 3, 3, 2, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 3, 3, 2, 3, 3, 3, 3, 3, 4, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 2, 4, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 2, 3, 3, 3, 3, 4, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3], "type": "box", "uid": "e121a158-c938-44fc-9ccd-8435516d9203"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [9, 7, 8, 1, 5, 2, 5, 10, 4, 7, 2, 1, 10, 0, 10, 2, 4, 2, 8, 4, 5, 5, 15, 6, 8, 1, 5, 4, 1, 13, 26, 9, 10, 2, 4, 2, 1, 0, 1, 9, 4, 4, 9, 8, 8, 0, 5, 4, 6, 5, 2, 3, 2, 10, 3, 5, 6, 12, 5, 31, 1, 8, 1, 3, 2, 2, 1, 1, 3, 6, 10, 6, 15, 3, 18, 11, 1, 9, 9, 9, 19, 3, 0, 3, 5, 5, 6, 18, 9, 5, 12, 2, 7, 1, 1, 7, 5, 5, 2, 4, 10, 1, 3, 4, 12, 4, 14, 10, 22, 1, 4, 2, 5, 1, 1, 1, 1, 12, 1, 1, 1, 2, 4, 15, 2, 7, 7, 9, 10, 27, 17, 6, 1, 3, 1, 5, 1, 10, 1, 11, 10, 6, 13, 5, 11, 22, 10, 3, 1, 16, 1, 8, 2, 0, 9, 5, 1, 11, 1, 20, 5, 40, 2, 15, 3, 3, 4, 6, 3, 5, 3, 5, 1, 17, 10, 1, 2, 5, 5, 1, 5, 9, 5, 5, 8, 12, 2, 3, 1, 2, 3, 3, 4, 8, 20, 10, 7, 33, 7, 1, 5, 20, 8, 6, 5, 1, 7, 2, 7, 5, 7, 1, 4, 8, 3, 6, 13, 10, 5, 4, 2, 22, 5, 9, 3, 2, 2, 11, 3, 3, 1, 19, 3, 4, 9, 1, 5, 6, 0, 6, 20, 36, 5, 3, 5, 7, 10, 5, 5, 17, 1, 2, 5, 3, 4, 0, 1, 4, 18, 9, 10, 5, 24, 2, 10, 21, 8, 7, 4, 7, 10, 21, 1, 10, 7, 6, 11, 11, 16, 5, 1, 7, 3, 7, 2, 3, 1, 5, 2, 5, 6, 2, 1, 18, 1, 25, 1, 4, 13, 3, 13, 4, 21, 10, 2, 5, 2, 5, 5, 29, 3, 5, 10, 2, 27, 5, 3, 5,  ...

# %% [markdown]
# ### Data Science Department

# %%
Data_Science = EmpPer[EmpPer.EmpDepartment == 'Data Science']
Data_Science.head()
# Out:
#     EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 89   E1001165   49  Female    Technical Degree       Married  Data Science
# 107  E1001201   21  Female               Other        Single  Data Science
# 108  E1001202   36    Male       Life Sciences       Married  Data Science
# 120  E1001223   48    Male             Medical       Married  Data Science
# 942   E100574   51    Male       Life Sciences       Married  Data Science
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 89   Data Scientist           Travel_Rarely                 1
# 107  Data Scientist           Travel_Rarely                18
# 108  Data Scientist           Travel_Rarely                14
# 120  Data Scientist           Travel_Rarely                20
# 942  Data Scientist           Travel_Rarely                 8
#
#      EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 89                   3        ...                                    2
# 107                  1        ...                                    1
# 108                  1        ...                                    1
# 120                  4        ...                                    1
# 942                  4        ...                                    4
#
#      TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 89                            7                      2                   3
# 107                           1                      3                   2
# 108                          17                      2                   2
# 120                          13                      2                   2
# 942                          16                      5                   1
#
#      ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 89                              4                             2
# 107                             1                             0
# 108                            16                             8
# 120                             0                             0
# 942                            10                             9
#
#     YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 89                        0                     2         No
# 107                       0                     0        Yes
# 108                       4                    11         No
# 120                       0                     0         No
# 942                       4                     7         No
#
#      PerformanceRating
# 89                   3
# 107                  3
# 108                  3
# 120                  3
# 942                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(Data_Science['PerformanceRating'], Data_Science['Age'],palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=Data_Science, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(Data_Science['Gender'], Data_Science['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# ### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': Data_Science['TotalWorkExperienceInYears'],
        'y': Data_Science['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':Data_Science['ExperienceYearsAtThisCompany'],
        'y':Data_Science['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': Data_Science['ExperienceYearsInCurrentRole'],
        'y': Data_Science['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Data Science ',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="5303a5c7-c817-4b49-89f4-290d2d1cf6d7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5303a5c7-c817-4b49-89f4-290d2d1cf6d7", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [7, 1, 17, 13, 16, 7, 17, 22, 10, 6, 5, 9, 21, 5, 31, 19, 1, 8, 18, 9], "y": [3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3], "type": "box", "uid": "e126b303-4f0c-4b59-a27b-66749f390985"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [4, 1, 16, 0, 10, 3, 1, 21, 9, 6, 3, 8, 3, 5, 5, 10, 1, 2, 1, 8], "y": [3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3], "type": "box", "uid": "8ecdfdd7-0032-4e53-a6d3-86dba9b337e1"}, {"boxmean": false, "marker": {"color": "#FF851B"}, "name": "ExperienceYearsInCurrentRole", "orientation": "h", "x": [2, 0, 8, 0, 9, 2, 0, 7, 0, 5, 2, 3, 2, 2, 2, 7, 0, 2, 0, 7], "y": [3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3], "type": "box", "uid": "e990d301-505b-4f79-ba0d-8f492c14beba"}], {"boxmode": "group", "title": "Performance According to the Experience Level - Data Science ", "xaxis": {"title": "Number Of Years", "zeroline": false}, "yaxis": {"title": "Performance Rating ", "zeroline": false}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("5303a5c7-c817-4b49-89f4-290d2d1cf6d7"));});</script>

# %% [markdown]
# ### Research & Development Department

# %%
RnD = EmpPer[EmpPer.EmpDepartment == 'Research & Development']
RnD.head()
# Out:
#     EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 156  E1001284   38    Male             Medical       Married
# 157  E1001288   35    Male               Other      Divorced
# 158  E1001289   31  Female       Life Sciences       Married
# 159  E1001290   18    Male       Life Sciences        Single
# 160  E1001291   54  Female    Technical Degree       Married
#
#               EmpDepartment              EmpJobRole BusinessTravelFrequency  \
# 156  Research & Development      Senior Manager R&D       Travel_Frequently
# 157  Research & Development   Laboratory Technician           Travel_Rarely
# 158  Research & Development  Manufacturing Director       Travel_Frequently
# 159  Research & Development      Research Scientist              Non-Travel
# 160  Research & Development      Senior Manager R&D           Travel_Rarely
#
#      DistanceFromHome  EmpEducationLevel        ...          \
# 156                10                  1        ...
# 157                14                  4        ...
# 158                 1                  1        ...
# 159                 5                  2        ...
# 160                17                  3        ...
#
#      EmpRelationshipSatisfaction  TotalWorkExperienceInYears  \
# 156                            2                           3
# 157                            4                           5
# 158                            3                           4
# 159                            4                           0
# 160                            3                          22
#
#      TrainingTimesLastYear  EmpWorkLifeBalance  ExperienceYearsAtThisCompany  \
# 156                      0                   2                             2
# 157                      2                   1                             4
# 158                      1                   3                             4
# 159                      2                   3                             0
# 160                      2                   3                            10
#
#      ExperienceYearsInCurrentRole YearsSinceLastPromotion  \
# 156                             1                       0
# 157                             2                       0
# 158                             3                       0
# 159                             0                       0
# 160                             7                       0
#
#      YearsWithCurrManager  Attrition  PerformanceRating
# 156                     2         No                  3
# 157                     2        Yes                  3
# 158                     3         No                  3
# 159                     0         No                  3
# 160                     8         No                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(RnD['PerformanceRating'], RnD['Age'], palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=RnD, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(RnD['Gender'], RnD['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': RnD['TotalWorkExperienceInYears'],
        'y': RnD['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':RnD['ExperienceYearsAtThisCompany'],
        'y':RnD['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': RnD['ExperienceYearsInCurrentRole'],
        'y': RnD['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - R & D',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="9e1efb20-1e07-47b4-9108-69bfdcf6608d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9e1efb20-1e07-47b4-9108-69bfdcf6608d", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [3, 5, 4, 0, 22, 16, 9, 8, 4, 19, 27, 8, 21, 4, 3, 8, 30, 17, 21, 21, 10, 9, 6, 8, 29, 8, 5, 18, 15, 31, 1, 19, 10, 6, 7, 20, 14, 3, 23, 14, 7, 7, 1, 23, 1, 6, 27, 18, 11, 10, 21, 21, 9, 18, 6, 5, 8, 16, 10, 3, 0, 6, 2, 9, 4, 20, 6, 1, 8, 16, 15, 14, 2, 28, 10, 1, 7, 14, 6, 26, 1, 6, 32, 25, 1, 7, 20, 2, 10, 17, 15, 20, 9, 33, 10, 1, 36, 6, 25, 23, 12, 7, 6, 25, 9, 1, 8, 34, 2, 25, 15, 5, 26, 4, 18, 18, 2, 8, 10, 10, 5, 2, 22, 21, 2, 10, 10, 10, 25, 23, 6, 10, 9, 7, 31, 7, 11, 29, 0, 10, 33, 5, 15, 10, 4, 14, 12, 13, 24, 20, 8, 5, 8, 10, 7, 20, 29, 32, 9, 10, 1, 6, 10, 17, 7, 5, 7, 7, 11, 11, 10, 24, 10, 16, 7, 20, 8, 6, 12, 1, 13, 29, 16, 16, 4, 8, 8, 1, 10, 4, 8, 14, 10, 26, 11, 11, 5, 15, 32, 4, 10, 9, 5, 8, 24, 15, 2, 8, 10, 1, 34, 7, 10, 1, 9, 10, 10, 15, 19, 10, 9, 9, 25, 3, 21, 6, 18, 6, 19, 10, 9, 9, 10, 6, 10, 6, 9, 12, 15, 6, 34, 11, 5, 27, 5, 1, 24, 15, 6, 14, 7, 15, 11, 7, 11, 6, 28, 15, 14, 23, 0, 15, 6, 11, 10, 7, 12, 11, 8, 29, 1, 19, 1, 11, 16, 4, 10, 22, 1, 24, 10, 5, 5, 18, 4, 8, 12, 6, 16, 16, 20, 8, 10, 28, 5, 4, 5, 8, 9, 6, 8, 9, 9, 10, 1, 20, 13, 9, 4, 5, 10, 12, 7, 25, 9, 12, 14, 5, 4, 10, 10, 6, 8, 18, 20, 16, 6, 18, 13, 4, 14, 21, 4, 8, 10, 20, 4, 10, 5, 10, 9, 6, 6], "y": [3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 3, 3, 3, 2, 2, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 4, 3, 4, 2, 2, 3, 3, 2, 2, 3, 2, 3, 3, 4, 3, 3, 3, 2, 2, 4, 3, 2, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 4, 3, 4, 2, 3, 2, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 4, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 4, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 2, 2, 3, 3, 3, 4, 3, 2, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 2, 2, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 2, 4, 3, 2, 3, 2, 3, 2, 2, 3, 3, 3, 3, 4, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 2, 3, 3, 4, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 2, 2, 3, 2, 4, 2, 3, 3, 4, 3, 3, 3, 3, 2, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 3, 3, 2, 3, 2, 3, 4, 3, 3, 4, 2, 3, 3, 3, 3, 4, 3, 4, 3, 4, 3, 2, 2, 3, 3, 3, 4, 2, 3, 2, 3, 3, 2, 3, 3, 3, 3, 4, 2, 3, 3, 3, 3, 3, 3, 4, 2, 4, 3, 3, 3, 4, 3, 2, 3, 3, 3, 3, 2, 3, 4, 2, 3, 3, 3, 2, 3, 3, 2, 2, 4, 2, 3, 4, 2, 2, 3, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3], "type": "box", "uid": "b273e7a2-bf93-4830-8352-c5ed5002c187"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [2, 4, 4, 0, 10, 16, 8, 8, 4, 2, 15, 2, 21, 3, 3, 1, 5, 8, 21, 21, 8, 1, 3, 2, 8, 4, 5, 5, 14, 9, 1, 16, 10, 5, 6, 19, 11, 3, 3, 13, 6, 7, 1, 22, 1, 0, 5, 8, 7, 9, 18, 20, 5, 11, 5, 3, 7, 1, 10, 3, 0, 1, 2, 6, 4, 18, 4, 1, 8, 1, 7, 13, 2, 5, 10, 1, 3, 14, 6, 7, 0, 0, 2, 4, 1, 7, 20, 2, 8, 7, 14, 1, 9, 5, 10, 1, 10, 6, 8, 1, 11, 1, 6, 1, 7, 1, 8, 33, 2, 9, 11, 4, 25, 3, 1, 16, 2, 7, 8, 7, 3, 2, 0, 19, 2, 10, 7, 9, 3, 19, 4, 9, 9, 3, 10, 4, 10, 5, 0, 9, 19, 5, 12, 8, 4, 14, 6, 6, 5, 20, 8, 4, 3, 2, 3, 4, 20, 9, 3, 4, 1, 5, 10, 6, 6, 3, 5, 4, 8, 1, 10, 7, 3, 9, 5, 3, 3, 5, 12, 1, 12, 8, 14, 2, 3, 5, 0, 1, 3, 3, 8, 0, 5, 14, 9, 11, 4, 5, 32, 1, 10, 7, 5, 5, 20, 15, 1, 2, 10, 1, 33, 5, 8, 1, 2, 10, 5, 15, 1, 10, 8, 5, 23, 3, 21, 5, 1, 6, 10, 10, 5, 9, 9, 6, 3, 5, 6, 7, 1, 1, 1, 9, 5, 3, 5, 1, 2, 12, 5, 10, 4, 7, 7, 3, 3, 5, 22, 7, 7, 2, 0, 1, 5, 11, 6, 2, 9, 7, 0, 22, 1, 5, 1, 3, 5, 3, 9, 19, 1, 22, 2, 5, 4, 13, 2, 7, 4, 5, 15, 8, 20, 4, 5, 5, 5, 4, 5, 7, 5, 4, 1, 4, 9, 10, 1, 20, 11, 5, 4, 5, 10, 12, 2, 17, 4, 5, 13, 2, 3, 10, 9, 6, 1, 7, 18, 16, 4, 4, 13, 2, 10, 20, 4, 2, 10, 5, 4, 4, 5, 9, 7, 6, 4], "y": [3, 3, 3, 3, 3, ...

# %% [markdown]
# ### Finance Department

# %%
Finance = EmpPer[EmpPer.EmpDepartment == 'Finance']
Finance.head()
# Out:
#     EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 482  E1001868   29   Male       Life Sciences      Divorced       Finance
# 484  E1001870   23   Male    Technical Degree       Married       Finance
# 485  E1001874   35   Male       Life Sciences       Married       Finance
# 486  E1001875   34   Male    Technical Degree       Married       Finance
# 487  E1001877   43   Male    Technical Degree      Divorced       Finance
#
#           EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 482  Finance Manager       Travel_Frequently                 2
# 484  Finance Manager           Travel_Rarely                10
# 485  Finance Manager           Travel_Rarely                28
# 486  Finance Manager       Travel_Frequently                10
# 487  Finance Manager           Travel_Rarely                27
#
#      EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 482                  1        ...                                    4
# 484                  3        ...                                    4
# 485                  3        ...                                    4
# 486                  4        ...                                    2
# 487                  3        ...                                    3
#
#      TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 482                           6                      0                   4
# 484                           4                      2                   3
# 485                          10                      3                   2
# 486                           8                      3                   2
# 487                           8                      0                   3
#
#      ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 482                             6                             4
# 484                             2                             2
# 485                            10                             9
# 486                             8                             2
# 487                             6                             4
#
#     YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 482                       1                     3         No
# 484                       2                     2         No
# 485                       6                     8         No
# 486                       7                     7         No
# 487                       0                     2         No
#
#      PerformanceRating
# 482                  2
# 484                  3
# 485                  2
# 486                  3
# 487                  3
#
# [5 rows x 28 columns]

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(Finance['PerformanceRating'], Finance['Age'], palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=Finance, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(Finance['Gender'], Finance['PerformanceRating'], palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': Finance['TotalWorkExperienceInYears'],
        'y': Finance['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':Finance['ExperienceYearsAtThisCompany'],
        'y':Finance['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': Finance['ExperienceYearsInCurrentRole'],
        'y': Finance['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Finance ',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="b04e7f74-6b37-4498-8b6c-98d84332573f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b04e7f74-6b37-4498-8b6c-98d84332573f", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [6, 4, 10, 8, 8, 1, 4, 32, 6, 23, 6, 10, 7, 9, 10, 7, 16, 6, 3, 11, 15, 9, 10, 10, 8, 18, 6, 5, 6, 7, 7, 27, 19, 11, 15, 30, 4, 13, 36, 14, 10, 17, 10, 5, 7, 11, 1, 7, 8], "y": [2, 3, 2, 3, 3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 2, 3, 3, 3, 4, 2, 3, 3, 2, 3, 3, 4, 2, 4, 3, 3, 3, 3, 3, 2, 3, 4, 2], "type": "box", "uid": "d86e5ae8-6aca-4494-9578-14936b1b3374"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [6, 2, 10, 8, 6, 1, 4, 30, 3, 22, 6, 10, 3, 9, 9, 7, 16, 5, 2, 10, 14, 4, 9, 5, 8, 4, 6, 3, 4, 7, 5, 4, 14, 11, 4, 15, 3, 5, 10, 14, 9, 2, 3, 5, 0, 4, 1, 7, 4], "y": [2, 3, 2, 3, 3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 2, 3, 3, 3, 4, 2, 3, 3, 2, 3, 3, 4, 2, 4, 3, 3, 3, 3, 3, 2, 3, 4, 2], "type": "box", "uid": "0062444d-70ad-4e36-b92c-8ad2c0568eda"}, {"boxmean": false, "marker": {"color": "#FF851B"}, "name": "ExperienceYearsInCurrentRole", "orientation": "h", "x": [4, 2, 9, 2, 4, 1, 2, 8, 2, 7, 4, 7, 2, 7, 6, 7, 15, 3, 2, 8, 11, 3, 2, 4, 4, 2, 3, 2, 2, 7, 4, 2, 11, 8, 3, 11, 2, 4, 8, 10, 5, 2, 2, 4, 0, 3, 0, 7, 2], "y": [2, 3, 2, 3, 3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 2, 3, 3, 3, 4, 2, 3, 3, 2, 3, 3, 4, 2, 4, 3, 3, 3, 3, 3, 2, 3, 4, 2], "type": "box", "uid": "680d210c-9fde-4469-abd3-ae9b461f0cc2"}], {"boxmode": "group", "title": "Performance According to the Experience Level - Finance ", "xaxis": {"title": "Number Of Years", "zeroline": false}, "yaxis": {"title": "Performance Rating ", "zeroline": false}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("b04e7f74-6b37-4498-8b6c-98d84332573f"));});</script>
