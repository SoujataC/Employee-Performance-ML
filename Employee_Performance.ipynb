# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Import Packages

# %%
# data analysis
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# for Plotly 
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go

# Machine Learning
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Acquiring the DataSet

# %%
file = r'Employee_Performance.xls'
EmpPer= pd.read_excel(file)

# %%
EmpPer.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# 0                  3        ...                                    4
# ...

# %% [markdown]
# ## Data Cleaning

# %%
EmpPer.isnull().values.any() #To find out NULL Values
# Out:
# False

# %%
EmpPer.isna().values.any() #To find out NaN Values
# Out:
# False

# %% [markdown]
# ## For quick overview of the DataFrame

# %% [markdown]
# The overview Includes list of all the Columns with their data types & number of non-null values in each column . Also it shows the value of RangeIndex for the Index Axis

# %%
EmpPer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %% [markdown]
# ## Statistical/Numerical Distribution of the DataFrame

# %%
EmpPer.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# ## Categorical Distribution of the DataFrame

# %%
EmpPer.describe(include=['O'])
# Out:
#        EmpNumber Gender EducationBackground MaritalStatus EmpDepartment  \
# count       1200   1200                1200          1200          1200
# unique      1200      2                   6             3             6
# top      E100898   Male       Life Sciences       Married         Sales
# freq           1    725                 492           548           373
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1200                    1200     1200      1200
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                270                     846      847      1022

# %% [markdown]
# ## Shape of the data

# %%
EmpPer.shape
# Out:
# (1200, 28)

# %% [markdown]
# ## Label Encoding

# %%
X=EmpPer.iloc[:,1:-1] #for integer-location based indexing / selection by position in the dataFrame
y=EmpPer.PerformanceRating

# %%
enc = LabelEncoder()
X.Gender = enc.fit_transform(X.Gender)
X.EducationBackground = enc.fit_transform(X.EducationBackground)
X.MaritalStatus = enc.fit_transform(X.MaritalStatus)
X.EmpDepartment = enc.fit_transform(X.EmpDepartment)
X.EmpJobRole = enc.fit_transform(X.EmpJobRole)
X.BusinessTravelFrequency = enc.fit_transform(X.BusinessTravelFrequency)
X.OverTime=enc.fit_transform(X.OverTime)
X.Attrition = enc.fit_transform(X.Attrition)
X.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    2              2              5          13
# 1   47       1                    2              2              5          13
# 2   40       1                    1              1              5          13
# 3   41       1                    0              0              3           8
# 4   60       1                    2              2              5          13
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        2                10                  3
# 1                        2                14                  4
# 2                        1                 5                  4
# 3                        2                10                  4
# 4                        2                16                  4
#
#    EmpEnvironmentSatisfaction    ...      EmpLastSalaryHikePercent  \
# ...

# %% [markdown]
# ## Using MACHINE LEARNING Models

# %% [markdown]
# ## Splitting Data into Train and Test sets

# %% [markdown]
# Before starting to train the Model, we need to divide the data into 2 sets -> Trainning Sets & -> Test Set

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=8)

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# Random forests is a supervised learning algorithm can be grouped under the category of ensemble models.Random forests creates decision trees on randomly selected data samples, gets prediction from each tree and selects the best solution by means of voting. It also provides a pretty good indicator of the feature importance.
#
# Random Forest is used over others because it does not suffer from the overfitting problem.It can also handle missing values with ease

# %%
model = RandomForestClassifier(n_estimators=16 ,max_depth = 7, random_state=8)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=7, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=16, n_jobs=None,
#             oob_score=False, random_state=8, verbose=0, warm_start=False)

# %% [markdown]
# # PREDICT MODEL

# %%
y_predict=model.predict(X_test)
print("Predictions finished")
# Out:
# Predictions finished

# %%
print(accuracy_score(y_test,y_predict))
# Out:
# 0.9533333333333334

# %% [markdown]
# ## 1. Top 3 Important Factors effecting employee performance

# %%
F_imp = pd.DataFrame(model.feature_importances_)
F_imp.index = X.columns
F_imp.columns = ['Employee performance']
F_imp.sort_values( by = 'Employee performance',ascending=False)
# Out:
#                               Employee performance
# EmpLastSalaryHikePercent                  0.239343
# EmpEnvironmentSatisfaction                0.227086
# YearsSinceLastPromotion                   0.134272
# EmpJobRole                                0.049215
# ExperienceYearsInCurrentRole              0.038640
# EmpDepartment                             0.030356
# ExperienceYearsAtThisCompany              0.029914
# EmpWorkLifeBalance                        0.028394
# Age                                       0.027255
# EmpHourlyRate                             0.026069
# TotalWorkExperienceInYears                0.022364
# YearsWithCurrManager                      0.021157
# DistanceFromHome                          0.014401
# EmpJobInvolvement                         0.012519
# TrainingTimesLastYear                     0.011170
# EmpRelationshipSatisfaction               0.010794
# MaritalStatus                             0.010232
# ...

# %% [markdown]
# ## 2. Department wise performances

# %% [markdown]
# The 6 departments are : -
#
# i) Sales
# ii) Human Resoruces
# iii) Development
# iv) Data Science
# v) Reserch & Development
# vi) Finamce

# %% [markdown]
# ### Sales Department

# %%
sales = EmpPer[EmpPer.EmpDepartment == 'Sales']  
sales.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single         Sales
# 1  E1001006   47   Male           Marketing        Single         Sales
# 2  E1001007   40   Male       Life Sciences       Married         Sales
# 4  E1001010   60   Male           Marketing        Single         Sales
# 6  E1001016   50   Male           Marketing       Married         Sales
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0       Sales Executive           Travel_Rarely                10
# 1       Sales Executive           Travel_Rarely                14
# 2       Sales Executive       Travel_Frequently                 5
# 4       Sales Executive           Travel_Rarely                16
# 6  Sales Representative           Travel_Rarely                 8
#
#    EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# ...

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(sales['PerformanceRating'], sales['Age'], palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=sales, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(sales['Gender'], sales['PerformanceRating'], palette="cubehelix")
# Out:
# C:\Users\princ\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': sales['TotalWorkExperienceInYears'],
        'y': sales['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':sales['ExperienceYearsAtThisCompany'],
        'y':sales['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': sales['ExperienceYearsInCurrentRole'],
        'y': sales['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Sales',
}
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="c05d543d-5775-4819-85a3-9d89bc652e0f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c05d543d-5775-4819-85a3-9d89bc652e0f", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [10, 20, 20, 10, 4, 28, 10, 1, 2, 34, 6, 9, 8, 6, 10, 6, 5, 3, 6, 6, 9, 12, 8, 29, 18, 35, 18, 9, 5, 10, 3, 28, 10, 8, 10, 2, 3, 10, 13, 9, 1, 1, 16, 17, 3, 5, 22, 10, 12, 9, 22, 12, 10, 9, 21, 19, 7, 33, 23, 19, 3, 26, 16, 14, 1, 8, 13, 18, 2, 5, 4, 15, 9, 23, 10, 3, 5, 22, 6, 6, 11, 22, 9, 10, 7, 1, 28, 8, 5, 15, 10, 5, 26, 26, 26, 4, 31, 23, 10, 9, 10, 10, 19, 10, 11, 10, 17, 5, 8, 24, 3, 5, 8, 14, 8, 4, 6, 6, 15, 1, 8, 6, 5, 13, 5, 15, 4, 11, 5, 16, 1, 1, 10, 11, 5, 23, 10, 9, 6, 7, 18, 8, 10, 9, 36, 10, 15, 11, 27, 10, 10, 0, 7, 2, 13, 10, 6, 10, 2,
# ...

# %% [markdown]
# ### Human Resoruces Department

# %%
HR = EmpPer[EmpPer.EmpDepartment == 'Human Resources']
HR.head()
# Out:
#    EmpNumber  Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 3   E1001009   41    Male     Human Resources      Divorced  Human Resources
# 16  E1001038   39  Female     Human Resources       Married  Human Resources
# 58  E1001107   36    Male     Human Resources       Married  Human Resources
# 81  E1001147   28    Male             Medical      Divorced  Human Resources
# 85  E1001156   36    Male       Life Sciences       Married  Human Resources
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 3           Manager           Travel_Rarely                10
# 16  Human Resources           Travel_Rarely                 3
# 58  Human Resources           Travel_Rarely                13
# 81  Human Resources           Travel_Rarely                 8
# 85  Human Resources           Travel_Rarely                 8
#
#     EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# ...

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(HR['PerformanceRating'], HR['Age'],palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=HR, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(HR['Gender'], HR['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': HR['TotalWorkExperienceInYears'],
        'y': HR['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':HR['ExperienceYearsAtThisCompany'],
        'y':HR['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': HR['ExperienceYearsInCurrentRole'],
        'y': HR['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - HR ',
    }
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="1495035b-effc-4255-877f-842147263dc3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1495035b-effc-4255-877f-842147263dc3", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [23, 12, 8, 6, 6, 13, 7, 6, 24, 6, 5, 10, 14, 10, 36, 33, 21, 10, 8, 2, 21, 10, 27, 14, 8, 10, 9, 3, 6, 10, 19, 13, 2, 3, 1, 10, 1, 7, 35, 6, 9, 16, 7, 23, 8, 12, 7, 9, 4, 1, 11, 32, 10, 16], "y": [3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 4, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 2, 3, 2, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 2, 2, 3, 3, 3, 2, 3, 3], "type": "box", "uid": "2ebac038-0e3c-4406-b43c-5665a43cb7fa"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [21, 8, 5, 5, 5, 5, 
# ...

# %% [markdown]
# ### Development Department

# %%
Development = EmpPer[EmpPer.EmpDepartment == 'Development']  
Development.head()
# Out:
#    EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 5   E1001011   27    Male       Life Sciences      Divorced   Development
# 7   E1001019   28  Female       Life Sciences        Single   Development
# 8   E1001020   36  Female       Life Sciences       Married   Development
# 9   E1001021   38  Female       Life Sciences        Single   Development
# 10  E1001022   44    Male             Medical        Single   Development
#
#    EmpJobRole BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 5   Developer       Travel_Frequently                10                  2
# 7   Developer           Travel_Rarely                 1                  2
# 8   Developer              Non-Travel                 8                  3
# 9   Developer           Travel_Rarely                 1                  3
# 10  Developer              Non-Travel                24                  3
#
#           ...          EmpRelationshipSatisfaction  \
# ...

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(Development['PerformanceRating'], Development['Age'],palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=Development, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(Development['Gender'], Development['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': Development['TotalWorkExperienceInYears'],
        'y': Development['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':Development['ExperienceYearsAtThisCompany'],
        'y':Development['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': Development['ExperienceYearsInCurrentRole'],
        'y': Development['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Development ',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="c7a3b1ab-74e5-4ab3-9403-98bce53b8b83" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c7a3b1ab-74e5-4ab3-9403-98bce53b8b83", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [9, 10, 10, 10, 9, 7, 10, 30, 5, 9, 19, 16, 10, 7, 10, 2, 5, 5, 11, 10, 9, 6, 17, 6, 8, 1, 9, 30, 1, 14, 26, 10, 10, 7, 8, 5, 10, 12, 1, 10, 13, 22, 9, 17, 8, 0, 10, 6, 6, 9, 4, 10, 8, 10, 4, 6, 8, 33, 12, 31, 1, 8, 3, 4, 6, 8, 1, 1, 6, 24, 10, 8, 15, 5, 20, 16, 1, 10, 9, 26, 20, 4, 3, 5, 8, 32, 6, 21, 9, 7, 22, 6, 8, 12, 1, 17, 6, 5, 3, 6, 10, 1, 6, 5, 13, 8, 26, 10, 24, 7, 9, 6, 6, 6, 1, 1, 1, 12, 8, 1, 23, 2, 10, 15, 4, 10, 7, 9, 10, 29, 17, 6, 25, 5, 2, 6, 1, 10, 5, 11, 10, 6, 17, 5, 11, 22, 21, 17, 1, 16, 17, 28, 2, 1, 9, 6, 12, 14, 7, 23, 5, 40, 3,
# ...

# %% [markdown]
# ### Data Science Department

# %%
Data_Science = EmpPer[EmpPer.EmpDepartment == 'Data Science']
Data_Science.head()
# Out:
#     EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 89   E1001165   49  Female    Technical Degree       Married  Data Science
# 107  E1001201   21  Female               Other        Single  Data Science
# 108  E1001202   36    Male       Life Sciences       Married  Data Science
# 120  E1001223   48    Male             Medical       Married  Data Science
# 942   E100574   51    Male       Life Sciences       Married  Data Science
#
#          EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 89   Data Scientist           Travel_Rarely                 1
# 107  Data Scientist           Travel_Rarely                18
# 108  Data Scientist           Travel_Rarely                14
# 120  Data Scientist           Travel_Rarely                20
# 942  Data Scientist           Travel_Rarely                 8
#
#      EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# ...

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(Data_Science['PerformanceRating'], Data_Science['Age'],palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=Data_Science, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(Data_Science['Gender'], Data_Science['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# ### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': Data_Science['TotalWorkExperienceInYears'],
        'y': Data_Science['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':Data_Science['ExperienceYearsAtThisCompany'],
        'y':Data_Science['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': Data_Science['ExperienceYearsInCurrentRole'],
        'y': Data_Science['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Data Science ',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="91ab5cd2-e2b6-4e08-9adf-86f641548d91" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("91ab5cd2-e2b6-4e08-9adf-86f641548d91", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [7, 1, 17, 13, 16, 7, 17, 22, 10, 6, 5, 9, 21, 5, 31, 19, 1, 8, 18, 9], "y": [3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3], "type": "box", "uid": "cb969685-f8bc-4fc6-9c6f-ef40c1b85132"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [4, 1, 16, 0, 10, 3, 1, 21, 9, 6, 3, 8, 3, 5, 5, 10, 1, 2, 1, 8], "y": [3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3], "type": "box", "uid": "e4b5a942-0a2c-4e0d-af99-58b829eae6c9"}, {"boxmean": false, "marker": {"color": "#FF851
# ...

# %% [markdown]
# ### Research & Development Department

# %%
RnD = EmpPer[EmpPer.EmpDepartment == 'Research & Development']
RnD.head()
# Out:
#     EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 156  E1001284   38    Male             Medical       Married
# 157  E1001288   35    Male               Other      Divorced
# 158  E1001289   31  Female       Life Sciences       Married
# 159  E1001290   18    Male       Life Sciences        Single
# 160  E1001291   54  Female    Technical Degree       Married
#
#               EmpDepartment              EmpJobRole BusinessTravelFrequency  \
# 156  Research & Development      Senior Manager R&D       Travel_Frequently
# 157  Research & Development   Laboratory Technician           Travel_Rarely
# 158  Research & Development  Manufacturing Director       Travel_Frequently
# 159  Research & Development      Research Scientist              Non-Travel
# 160  Research & Development      Senior Manager R&D           Travel_Rarely
#
#      DistanceFromHome  EmpEducationLevel        ...          \
# 156                10                  1        ...
# ...

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(RnD['PerformanceRating'], RnD['Age'], palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=RnD, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(RnD['Gender'], RnD['PerformanceRating'],palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': RnD['TotalWorkExperienceInYears'],
        'y': RnD['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':RnD['ExperienceYearsAtThisCompany'],
        'y':RnD['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': RnD['ExperienceYearsInCurrentRole'],
        'y': RnD['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - R & D',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="8404c669-9253-4bf8-9899-04d95a3c7d5c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8404c669-9253-4bf8-9899-04d95a3c7d5c", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [3, 5, 4, 0, 22, 16, 9, 8, 4, 19, 27, 8, 21, 4, 3, 8, 30, 17, 21, 21, 10, 9, 6, 8, 29, 8, 5, 18, 15, 31, 1, 19, 10, 6, 7, 20, 14, 3, 23, 14, 7, 7, 1, 23, 1, 6, 27, 18, 11, 10, 21, 21, 9, 18, 6, 5, 8, 16, 10, 3, 0, 6, 2, 9, 4, 20, 6, 1, 8, 16, 15, 14, 2, 28, 10, 1, 7, 14, 6, 26, 1, 6, 32, 25, 1, 7, 20, 2, 10, 17, 15, 20, 9, 33, 10, 1, 36, 6, 25, 23, 12, 7, 6, 25, 9, 1, 8, 34, 2, 25, 15, 5, 26, 4, 18, 18, 2, 8, 10, 10, 5, 2, 22, 21, 2, 10, 10, 10, 25, 23, 6, 10, 9, 7, 31, 7, 11, 29, 0, 10, 33, 5, 15, 10, 4, 14, 12, 13, 24, 20, 8, 5, 8, 10, 7, 20, 29, 32, 9
# ...

# %% [markdown]
# ### Finance Department

# %%
Finance = EmpPer[EmpPer.EmpDepartment == 'Finance']
Finance.head()
# Out:
#     EmpNumber  Age Gender EducationBackground MaritalStatus EmpDepartment  \
# 482  E1001868   29   Male       Life Sciences      Divorced       Finance
# 484  E1001870   23   Male    Technical Degree       Married       Finance
# 485  E1001874   35   Male       Life Sciences       Married       Finance
# 486  E1001875   34   Male    Technical Degree       Married       Finance
# 487  E1001877   43   Male    Technical Degree      Divorced       Finance
#
#           EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 482  Finance Manager       Travel_Frequently                 2
# 484  Finance Manager           Travel_Rarely                10
# 485  Finance Manager           Travel_Rarely                28
# 486  Finance Manager       Travel_Frequently                10
# 487  Finance Manager           Travel_Rarely                27
#
#      EmpEducationLevel        ...          EmpRelationshipSatisfaction  \
# ...

# %% [markdown]
# #### i) Performance Rating with respect to Age Group

# %%
sns.boxplot(Finance['PerformanceRating'], Finance['Age'], palette="Set2")

# %% [markdown]
# #### ii) Performance Rating with respect to number of employees

# %%
sns.countplot(y="PerformanceRating", data=Finance, palette="hls");

# %% [markdown]
# #### iii) Performance based on Gender

# %%
sns.barplot(Finance['Gender'], Finance['PerformanceRating'], palette="cubehelix")

# %% [markdown]
# #### iv) Performance According to the Experience Level

# %%
data = [
    {
        'x': Finance['TotalWorkExperienceInYears'],
        'y': Finance['PerformanceRating'],
        'name':'TotalWorkExperienceInYears',
        'marker': {
            'color': '#3D9970'
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x':Finance['ExperienceYearsAtThisCompany'],
        'y':Finance['PerformanceRating'],
        'name': 'ExperienceYearsAtThisCompany',
        'marker':{
            'color': '#FF4136',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    },
    {
        'x': Finance['ExperienceYearsInCurrentRole'],
        'y': Finance['PerformanceRating'],
        'name':'ExperienceYearsInCurrentRole',
        'marker': {
            'color': '#FF851B',
        },
        'boxmean': False,
        'orientation': 'h',
        "type": "box",
    }
]
layout = {
    'xaxis': {
        'title': 'Number Of Years',
        'zeroline': False,
    },
    'yaxis': {
        'title': 'Performance Rating ',
        'zeroline': False,
    },
    'boxmode': 'group',
    'title': 'Performance According to the Experience Level - Finance ',
}
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# <div id="7b406e9b-5165-476f-b7dd-2e6ef57b3a17" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7b406e9b-5165-476f-b7dd-2e6ef57b3a17", [{"boxmean": false, "marker": {"color": "#3D9970"}, "name": "TotalWorkExperienceInYears", "orientation": "h", "x": [6, 4, 10, 8, 8, 1, 4, 32, 6, 23, 6, 10, 7, 9, 10, 7, 16, 6, 3, 11, 15, 9, 10, 10, 8, 18, 6, 5, 6, 7, 7, 27, 19, 11, 15, 30, 4, 13, 36, 14, 10, 17, 10, 5, 7, 11, 1, 7, 8], "y": [2, 3, 2, 3, 3, 3, 2, 2, 3, 2, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 2, 3, 3, 3, 4, 2, 3, 3, 2, 3, 3, 4, 2, 4, 3, 3, 3, 3, 3, 2, 3, 4, 2], "type": "box", "uid": "ad4e3e35-a8db-4478-8b28-5cfc475b5e21"}, {"boxmean": false, "marker": {"color": "#FF4136"}, "name": "ExperienceYearsAtThisCompany", "orientation": "h", "x": [6, 2, 10, 8, 6, 1, 4, 30, 3, 22, 6, 10, 3, 9, 9, 7, 16
# ...
